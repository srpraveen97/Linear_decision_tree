# %%
class LinearDecisionTree:
    
    def __init__(self,criterion='MSE',max_depth=None,min_samples_split=100,min_samples_leaf=50,
                 max_features='max',random_state=42,linear_model=lm.Ridge(),feature_value):
        
        self.criterion = criterion
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.min_samples_leaf = min_samples_leaf
        self.max_features = max_features
        self.feature_value = feature_value
        
    def fit(self,X,y):
        
        pass
    
    def predict(self,X):
        
        pass
    
    def score(self,X,y):
        
        pass
    
    def get_depth(self):
        
        pass
    
    def get_n_leaves(self):
        
        pass
    
    def get_params(self):
        
        pass
    
    def path_taken(self):
        
        pass

# %%
class Tree:
    
    def __init__(self,criterion='MSE',max_depth=None,min_samples_split=100,min_samples_leaf=50,
                 max_features='max',random_state=42,linear_model=lm.Ridge(),feature_value):
        
        self.criterion = criterion
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.min_samples_leaf = min_samples_leaf
        self.max_features = max_features
        self.linear_model = linear_model
        self.feature_value = feature_value
    
    def build_tree(X,y,min_samples_split):
        
        decision_path = []
        
        root_node_split = Tree.best_split(X,y,self.criterion,self.min_samples_leaf,self.linear_model)
        
        while X.shape[0] > min_samples_split:
            
                

    @staticmethod
    def best_split(X,y,criterion,min_samples_leaf,linear_model):
    
        features = X.columns
        mse = []
        mae = []
        feat_pivot = []
        
        for feature in features:
            for pivot_value in feature_values[feature]:
                
                (X_l,y_l),(X_r,y_r) = Tree.split_node(X,y,feature,pivot_value)
                
                if X_l.shape[0] <= min_samples_leaf and X_r.shape[0] <= min_samples_leaf:
                
                    model_l = linear_model.fit(X_l.to_numpy(),y_l.to_numpy().reshape(-1,1))
                    model_r = linear_model.fit(X_r.to_numpy(),y_r.to_numpy().reshape(-1,1))
                    
                    if criterion == 'MAE':
                        total_mae = np.sum(np.abs(y_l.to_numpy().reshape(-1,1) - model_l.predict(X_l))) + np.sum(np.abs(y_r.to_numpy().reshape(-1,1) - model_r.predict(X_r)))
                        mae.append(total_mae) 
                        
                    else:
                        total_mse = np.sum(np.square(y_l.to_numpy().reshape(-1,1) - model_l.predict(X_l))) + np.sum(np.square(y_r.to_numpy().reshape(-1,1) - model_r.predict(X_r)))
                        mse.append(total_mse)
                        
                    feat_pivot.append((feature,pivot_value))
        
        if criterion == 'MAE':
            try:
                feature,pivot_value = feat_pivot[np.argmin(mae)]
                return {'feature_value':(feature,pivot_value),'Split_data':Tree.split_node(X,y,feature,pivot_value)}
            except:
                return 'Leaf'
        else:
            try:
                feature,pivot_value = feat_pivot[np.argmin(mse)]
                return {'feature_value':(feature,pivot_value),'Split_data':Tree.split_node(X,y,feature,pivot_value)}
            except:
                return 'Leaf'

    
    @staticmethod
    def split_node(X,y,feature,pivot_value):
    
        if X[feature].dtype.name is 'category':

            left = pd.concat([X,y],axis=1)[pd.concat([X,y],axis=1)[feature]!=pivot_value]
            right = pd.concat([X,y],axis=1)[pd.concat([X,y],axis=1)[feature]==pivot_value]
            left_node = (left.loc[:,left.columns != list(y.columns)[0]],left.loc[:,left.columns == list(y.columns)[0]])
            right_node = (right.loc[:,right.columns != list(y.columns)[0]],right.loc[:,right.columns == list(y.columns)[0]])

        else:

            sort_indices = X[feature].argsort()
            X_sorted = X.iloc[sort_indices]
            y_sorted = y.iloc[sort_indices]

            index = np.argmax(X_sorted[feature] >= pivot_value)

            left_node = (X_sorted.iloc[:index],y_sorted.iloc[:index])
            right_node = (X_sorted.iloc[index:],y_sorted.iloc[index:])

        return left_node,right_node
